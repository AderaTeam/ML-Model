# %%
import numpy as np
import pandas as pd

# %%
GDP = np.random.rand(100)

# %%
GDP
# Out:
# array([0.14792759, 0.2260451 , 0.17243301, 0.25098222, 0.80388633,
#        0.44297911, 0.48511165, 0.64659378, 0.96960217, 0.52756909,
#        0.82580376, 0.35694333, 0.76789326, 0.60027605, 0.22100531,
#        0.44955415, 0.44183099, 0.63915977, 0.63171032, 0.84377123,
#        0.89795236, 0.30187609, 0.30493893, 0.62632821, 0.22642681,
#        0.19307758, 0.19477444, 0.07382736, 0.74635553, 0.80490583,
#        0.21545568, 0.79664098, 0.94844542, 0.47596768, 0.92858088,
#        0.28438812, 0.01794807, 0.5035177 , 0.85692173, 0.47728057,
#        0.89048589, 0.63970728, 0.73656388, 0.95989677, 0.65656278,
#        0.52637204, 0.49261663, 0.04256078, 0.88790453, 0.79672965,
#        0.85611225, 0.31659498, 0.57517454, 0.2229157 , 0.90346978,
#        0.19947328, 0.17866966, 0.00757577, 0.96583674, 0.0644607 ,
#        0.86961855, 0.34761569, 0.20377683, 0.1848061 , 0.90178224,
#        0.83067981, 0.86135688, 0.99346062, 0.07727425, 0.57817464,
# ...
